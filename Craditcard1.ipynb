# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"/content/creditcard (1).csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data.duplicated().sum()
# Out:
# np.int64(1081)

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
#class distribution
data['Class'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Class'>

# %% [markdown]
# After class distribution i observe that 1.majority of transactions are genuine(class = 0)
# 2.very few are fraudulent(class = 1)
# # 3.The data set is highly imbalanced

# %%
#Distribution of Transaction Amount
plt.figure(figsize=(8,5))
sns.histplot(data['Amount'],bins = 50)
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
#Distribution of Time
plt.figure(figsize=(8,5))
sns.histplot(data['Time'], bins=50)
# Out:
# <Axes: xlabel='Time', ylabel='Count'>

# %%
#Correlation Heatmap
plt.figure(figsize=(18, 14))
sns.heatmap(data.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %%
#Boxplot of Amount
plt.figure(figsize=(8,5))
sns.boxplot(x=data['Amount'])
# Out:
# <Axes: xlabel='Amount'>

# %%
#Fraud vs Genuine Amount Comparison
plt.figure(figsize=(6,4))
sns.boxplot(x='Class', y='Amount', data=data)
# Out:
# <Axes: xlabel='Class', ylabel='Amount'>

# %%
#Correlation with Target (Class)
corr = data.corr()['Class'].sort_values()

plt.figure(figsize=(8,10))
corr.plot(kind='barh')
# Out:
# <Axes: >

# %%
#Separate Features and Target
X = data.drop("Class", axis=1)
y = data["Class"]

# %%
#Split the Dataset
from sklearn.model_selection import train_test_split
X_train,   X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42,stratify = y
)

# %%
#Scale the Amount Feature
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train["Amount"] = scaler.fit_transform(X_train[["Amount"]])
X_test["Amount"] = scaler.transform(X_test[["Amount"]])

# %%
#Handle Class Imbalance using SMOTE
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# %%
print(X_train.shape)
print(y_train.value_counts())
# Out:
# (453204, 30)
# Class
# 0    226602
# 1    226602
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score
)

# %%
results = []

# %%
def evaluate_model(model_name, y_test, y_pred, y_score):
    results.append({
        "Model": model_name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1 Score": f1_score(y_test, y_pred),
        "ROC AUC": roc_auc_score(y_test, y_score)
    })

# %%
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model_lr.predict(X_test)
y_prob = model_lr.predict_proba(X_test)[:,1]

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_prob
# Out:
# array([0.04584276, 0.00133423, 0.07521977, ..., 0.01553552, 0.04307471,
#        0.02961073])

# %%
evaluate_model("Logistic Regression", y_test, y_pred, y_prob)

# %%
print("confusion_matrix:",confusion_matrix(y_test,y_pred))
# Out:
# confusion_matrix: [[55666   985]
#  [   12    83]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56651
#            1       0.08      0.87      0.14        95
#
#     accuracy                           0.98     56746
#    macro avg       0.54      0.93      0.57     56746
# weighted avg       1.00      0.98      0.99     56746

# %%
model_NB = GaussianNB()
model_NB.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model_NB.predict(X_test)
y_prob = model_NB.predict_proba(X_test)[:,1]

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_prob
# Out:
# array([1.32536485e-10, 9.94573181e-11, 6.41922119e-09, ...,
#        1.65342165e-10, 3.54561861e-10, 5.93552581e-10])

# %%
evaluate_model("Naive Bayes", y_test, y_pred, y_prob)

# %%
print("confusion_matrix:",confusion_matrix(y_test,y_pred))
# Out:
# confusion_matrix: [[56189   462]
#  [   23    72]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56651
#            1       0.13      0.76      0.23        95
#
#     accuracy                           0.99     56746
#    macro avg       0.57      0.87      0.61     56746
# weighted avg       1.00      0.99      0.99     56746

# %%
model_DT = DecisionTreeClassifier(random_state=42)
model_DT.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model_DT.predict(X_test)
y_prob= model_DT.predict_proba(X_test)[:,1]

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_prob
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
evaluate_model("Decision Tree", y_test, y_pred, y_prob)

# %%
print("confusion_matrix:",confusion_matrix(y_test,y_pred))
# Out:
# confusion_matrix: [[56573    78]
#  [   24    71]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56651
#            1       0.48      0.75      0.58        95
#
#     accuracy                           1.00     56746
#    macro avg       0.74      0.87      0.79     56746
# weighted avg       1.00      1.00      1.00     56746

# %%
model_svm = LinearSVC(random_state=42)
model_svm.fit(X_train, y_train)
# Out:
# LinearSVC(random_state=42)

# %%
y_pred = model_svm.predict(X_test)
y_score = model_svm.decision_function(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_score
# Out:
# array([-0.56956602, -1.23830704, -0.24192635, ..., -0.72643853,
#        -0.77038258, -0.29545354])

# %%
evaluate_model("SVM", y_test, y_pred, y_score)

# %%
print("confusion_matrix:",confusion_matrix(y_test,y_pred))
# Out:
# confusion_matrix: [[55960   691]
#  [   16    79]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56651
#            1       0.10      0.83      0.18        95
#
#     accuracy                           0.99     56746
#    macro avg       0.55      0.91      0.59     56746
# weighted avg       1.00      0.99      0.99     56746

# %%
model_knn = KNeighborsClassifier(n_neighbors = 5)
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model_knn.predict(X_test)
y_prob = model_knn.predict_proba(X_test)[:,1]

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
y_prob
# Out:
# array([0. , 0. , 0.6, ..., 0. , 0. , 0. ])

# %%
evaluate_model("KNN", y_test, y_pred, y_prob)

# %%
print("confusion_matrix:",confusion_matrix(y_test,y_pred))
# Out:
# confusion_matrix: [[55679   972]
#  [   30    65]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56651
#            1       0.06      0.68      0.11        95
#
#     accuracy                           0.98     56746
#    macro avg       0.53      0.83      0.55     56746
# weighted avg       1.00      0.98      0.99     56746

# %%
model_rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model_rf.predict(X_test)
y_prob= model_rf.predict_proba(X_test)[:,1]

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_prob
# Out:
# array([0.  , 0.  , 0.01, ..., 0.  , 0.  , 0.  ])

# %%
evaluate_model(
    "Random Forest",
    y_test,
    y_pred,
    y_prob
)

# %%
print("confusion_matrix:",confusion_matrix(y_test,y_pred))
# Out:
# confusion_matrix: [[56644     7]
#  [   22    73]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56651
#            1       0.91      0.77      0.83        95
#
#     accuracy                           1.00     56746
#    macro avg       0.96      0.88      0.92     56746
# weighted avg       1.00      1.00      1.00     56746

# %%
comparison = pd.DataFrame(results)

# %%
comparison
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 0  Logistic Regression  0.982430   0.077715  0.873684  0.142734  0.967651
# 1          Naive Bayes  0.991453   0.134831  0.757895  0.228935  0.956104
# 2        Decision Tree  0.998203   0.476510  0.747368  0.581967  0.872996
# 3                  SVM  0.987541   0.102597  0.831579  0.182659  0.960262
# 4                  KNN  0.982342   0.062681  0.684211  0.114841  0.850504
# 5        Random Forest  0.999489   0.912500  0.768421  0.834286  0.961093

# %%
import joblib
joblib.dump(model_rf, 'random_forest_creditcard.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(X.columns.tolist(), 'columns.pkl')
# Out:
# ['columns.pkl']
